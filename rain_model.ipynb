# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

rain_model = pd.read_pickle("rain_model.pkl")
rain19 = pd.read_csv("2019_rainfall.csv")
# rain_model['rained'] = rain19['rained']
# rain_model['credit'] = df[df.year == 2019].groupby('date').sum()['credit'].tolist()

# %%
rain19['amount_mm'].plot()
plt.show()
rain19
# Out:
#      year  month  day  amount_mm  days_agg quality        date
# 0    2019      1    1        0.0         0       N  2019-01-01
# 1    2019      1    2        0.0         0       N  2019-01-02
# 2    2019      1    3        0.0         0       N  2019-01-03
# 3    2019      1    4        0.0         0       N  2019-01-04
# 4    2019      1    5        0.0         0       N  2019-01-05
# ..    ...    ...  ...        ...       ...     ...         ...
# 360  2019     12   27        0.0         0       N  2019-12-27
# 361  2019     12   28        0.0         0       N  2019-12-28
# 362  2019     12   29        0.0         0       N  2019-12-29
# 363  2019     12   30        0.0         0       N  2019-12-30
# 364  2019     12   31        0.0         0       N  2019-12-31
#
# [365 rows x 7 columns]

# %%
# rain_model['credit'].hist(by=rain_model['rained'])
sns.kdeplot(rain_model[rain_model.rained == 1]['credit'])
sns.kdeplot(rain_model[rain_model.rained == 0]['credit'])
plt.show()

# %%
x = np.array(rain_model.rained).reshape(1, -1)
y = np.array(rain_model.credit)
reg = LogisticRegression().fit(x, y)
reg.score()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-41-c64d64b0e46e> in <module>
#       1 x = np.array(rain_model.rained).reshape(1, -1)
#       2 y = np.array(rain_model.credit).reshape(1, -1)
# ----> 3 reg = LogisticRegression().fit(x, y)
#       4 reg.score()
#
# ~/.virtualenvs/alterations/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py in fit(self, X, y, sample_weight)
#    1340             _dtype = [np.float64, np.float32]
#    1341
# -> 1342         X, y = self._validate_data(X, y, accept_sparse='csr', dtype=_dtype,
#    1343                                    order="C",
#    1344                                    accept_large_sparse=solver != 'liblinear')
#
# ~/.virtualenvs/alterations/lib/python3.8/site-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     430                 y = check_array(y, **check_y_params)
#     431             else:
# --> 432                 X, y = check_X_y(X, y, **check_params)
#     433             out = X, y
#     434
#
# ~/.virtualenvs/alterations/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      71                           FutureWarning)
#      72         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 73         return f(**kwargs)
#      74     return inner_f
#      75
#
# ~/.virtualenvs/alterations/lib/python3.8/site-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#     806                         ensure_2d=False, dtype=None)
#     807     else:
# --> 808         y = column_or_1d(y, warn=True)
#     809         _assert_all_finite(y)
#     810     if y_numeric and y.dtype.kind == 'O':
#
# ~/.virtualenvs/alterations/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      71                           FutureWarning)
#      72         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 73         return f(**kwargs)
#      74     return inner_f
#      75
#
# ~/.virtualenvs/alterations/lib/python3.8/site-packages/sklearn/utils/validation.py in column_or_1d(y, warn)
#     844         return np.ravel(y)
#     845
# --> 846     raise ValueError(
#     847         "y should be a 1d array, "
#     848         "got an array of shape {} instead.".format(shape))
#
# ValueError: y should be a 1d array, got an array of shape (1, 365) instead.
